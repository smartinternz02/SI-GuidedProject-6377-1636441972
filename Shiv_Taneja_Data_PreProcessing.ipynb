# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Survival.csv")

# %%
data
# Out:
#      PassengerId                                          Name  \
# 0            892                              Kelly, Mr. James
# 1            893              Wilkes, Mrs. James (Ellen Needs)
# 2            894                     Myles, Mr. Thomas Francis
# 3            895                              Wirz, Mr. Albert
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...                                           ...
# 413         1305                            Spector, Mr. Woolf
# 414         1306                  Oliva y Ocana, Dona. Fermina
# 415         1307                  Saether, Mr. Simon Sivertsen
# 416         1308                           Ware, Mr. Frederick
# 417         1309                      Peter, Master. Michael J
#
#                  Ticket Cabin      Fare Embarked  Pclass     Sex   Age  SibSp  \
# 0                330911   NaN    7.8292        Q       3    male  34.5      0
# 1                363272   NaN    7.0000        S       3  female  47.0      1
# 2                240276   NaN    9.6875        Q       2    male  62.0      0
# 3                315154   NaN    8.6625        S       3    male  27.0      0
# 4               3101298   NaN   12.2875        S       3  female  22.0      1
# ..                  ...   ...       ...      ...     ...     ...   ...    ...
# 413           A.5. 3236   NaN    8.0500        S       3    male   NaN      0
# 414            PC 17758  C105  108.9000        C       1  female  39.0      0
# 415  SOTON/O.Q. 3101262   NaN    7.2500        S       3    male  38.5      0
# 416              359309   NaN    8.0500        S       3    male   NaN      0
# 417                2668   NaN   22.3583        C       3    male   NaN      1
#
#      Parch  Survived
# 0        0         0
# 1        0         1
# 2        0         0
# 3        0         0
# 4        1         1
# ..     ...       ...
# 413      0         0
# 414      0         1
# 415      0         0
# 416      0         0
# 417      1         0
#
# [418 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Name         418 non-null    object
#  2   Ticket       418 non-null    object
#  3   Cabin        91 non-null     object
#  4   Fare         417 non-null    float64
#  5   Embarked     418 non-null    object
#  6   Pclass       418 non-null    int64
#  7   Sex          418 non-null    object
#  8   Age          332 non-null    float64
#  9   SibSp        418 non-null    int64
#  10  Parch        418 non-null    int64
#  11  Survived     418 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %% [markdown]
# ## Dealing with missing values

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Name             0
# Ticket           0
# Cabin          327
# Fare             1
# Embarked         0
# Pclass           0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Survived         0
# dtype: int64

# %%
#Dealing with Fare
data['Fare'].fillna(data['Fare'].median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Name             0
# Ticket           0
# Cabin          327
# Fare             0
# Embarked         0
# Pclass           0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Survived         0
# dtype: int64

# %%
#Dealing with Cabin
data.drop('Cabin',axis=1,inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId     0
# Name            0
# Ticket          0
# Fare            0
# Embarked        0
# Pclass          0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Survived        0
# dtype: int64

# %%
data.drop(data[np.isnan(data['Age'])==True].index,inplace=True)

# %%
data.isnull().any()
# Out:
# PassengerId    False
# Name           False
# Ticket         False
# Fare           False
# Embarked       False
# Pclass         False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Survived       False
# dtype: bool

# %% [markdown]
# ## Seperate, dependent and independent variables

# %%
data
# Out:
#      PassengerId                                             Name  \
# 0            892                                 Kelly, Mr. James
# 1            893                 Wilkes, Mrs. James (Ellen Needs)
# 2            894                        Myles, Mr. Thomas Francis
# 3            895                                 Wirz, Mr. Albert
# 4            896     Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...                                              ...
# 409         1301                        Peacock, Miss. Treasteall
# 411         1303  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1304                   Henriksson, Miss. Jenny Lovisa
# 414         1306                     Oliva y Ocana, Dona. Fermina
# 415         1307                     Saether, Mr. Simon Sivertsen
#
#                  Ticket      Fare Embarked  Pclass     Sex   Age  SibSp  \
# 0                330911    7.8292        Q       3    male  34.5      0
# 1                363272    7.0000        S       3  female  47.0      1
# 2                240276    9.6875        Q       2    male  62.0      0
# 3                315154    8.6625        S       3    male  27.0      0
# 4               3101298   12.2875        S       3  female  22.0      1
# ..                  ...       ...      ...     ...     ...   ...    ...
# 409  SOTON/O.Q. 3101315   13.7750        S       3  female   3.0      1
# 411               19928   90.0000        Q       1  female  37.0      1
# 412              347086    7.7750        S       3  female  28.0      0
# 414            PC 17758  108.9000        C       1  female  39.0      0
# 415  SOTON/O.Q. 3101262    7.2500        S       3    male  38.5      0
#
#      Parch  Survived
# 0        0         0
# 1        0         1
# 2        0         0
# 3        0         0
# 4        1         1
# ..     ...       ...
# 409      1         1
# 411      0         1
# 412      0         1
# 414      0         1
# 415      0         0
#
# [332 rows x 11 columns]

# %%
x=data.iloc[:,4:10]
x  #Independent Variables
# Out:
#     Embarked  Pclass     Sex   Age  SibSp  Parch
# 0          Q       3    male  34.5      0      0
# 1          S       3  female  47.0      1      0
# 2          Q       2    male  62.0      0      0
# 3          S       3    male  27.0      0      0
# 4          S       3  female  22.0      1      1
# ..       ...     ...     ...   ...    ...    ...
# 409        S       3  female   3.0      1      1
# 411        Q       1  female  37.0      1      0
# 412        S       3  female  28.0      0      0
# 414        C       1  female  39.0      0      0
# 415        S       3    male  38.5      0      0
#
# [332 rows x 6 columns]

# %%
y=data.iloc[:,10:]
y
# Out:
#      Survived
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
# ..        ...
# 409         1
# 411         1
# 412         1
# 414         1
# 415         0
#
# [332 rows x 1 columns]

# %% [markdown]
# ## Encode the categorical columns

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
x['Sex']=le.fit_transform(x['Sex'])
x['Embarked']=le.fit_transform(x['Embarked'])
x
# Out:
#      Embarked  Pclass  Sex   Age  SibSp  Parch
# 0           1       3    1  34.5      0      0
# 1           2       3    0  47.0      1      0
# 2           1       2    1  62.0      0      0
# 3           2       3    1  27.0      0      0
# 4           2       3    0  22.0      1      1
# ..        ...     ...  ...   ...    ...    ...
# 409         2       3    0   3.0      1      1
# 411         1       1    0  37.0      1      0
# 412         2       3    0  28.0      0      0
# 414         0       1    0  39.0      0      0
# 415         2       3    1  38.5      0      0
#
# [332 rows x 6 columns]

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.5110897 ,  1.01232494,  0.78709097,  0.29854934, -0.55218394,
#         -0.49119871],
#        [ 0.65111428,  1.01232494, -1.27050117,  1.18132793,  0.59359773,
#         -0.49119871],
#        [-0.5110897 , -0.17109717,  0.78709097,  2.24066224, -0.55218394,
#         -0.49119871],
#        ...,
#        [ 0.65111428,  1.01232494, -1.27050117, -0.16049553, -0.55218394,
#         -0.49119871],
#        [-1.67329369, -1.35451929, -1.27050117,  0.61634963, -0.55218394,
#         -0.49119871],
#        [ 0.65111428,  1.01232494,  0.78709097,  0.58103849, -0.55218394,
#         -0.49119871]])

# %% [markdown]
# ## Splitting training and test data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (265, 6)
# (67, 6)
# (265, 1)
# (67, 1)

# %% [markdown]
# # End!
